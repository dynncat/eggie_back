# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
class RealisticBabySimulator:
    def __init__(self, baby_ids, start_date, total_weeks=8):
        self.baby_ids = baby_ids
        self.start_date = start_date
        self.total_weeks = total_weeks
        self.log_interval_seconds = 10
        self.logs_per_minute = 60 // self.log_interval_seconds
        
        # 주차별 발달 단계: (기본수면확률, 평균 낮잠 시간(분), 최대 깨어있는 시간(분), 야간수면강화, 밤중깸확률)
        # 밤중깸확률: 밤 시간 동안, 잠든 상태에서 짧게 깰(브레이크) 확률 (기본값)
        self.developmental_stages = {
            0:  {'base_sleep_prob': 0.60, 'avg_nap_duration_min': 45, 'max_awake_min': 60,  'night_sleep_factor': 1.3, 'night_break_prob': 0.15}, # 신생아
            1:  {'base_sleep_prob': 0.58, 'avg_nap_duration_min': 50, 'max_awake_min': 75,  'night_sleep_factor': 1.3, 'night_break_prob': 0.12},
            4:  {'base_sleep_prob': 0.55, 'avg_nap_duration_min': 60, 'max_awake_min': 90,  'night_sleep_factor': 1.25,'night_break_prob': 0.10}, # 1개월
            8:  {'base_sleep_prob': 0.50, 'avg_nap_duration_min': 75, 'max_awake_min': 100, 'night_sleep_factor': 1.2, 'night_break_prob': 0.08}, # 2개월
            16: {'base_sleep_prob': 0.45, 'avg_nap_duration_min': 90, 'max_awake_min': 120, 'night_sleep_factor': 1.15,'night_break_prob': 0.06}, # 4개월 (수면퇴행기 고려 필요시 별도 로직)
            24: {'base_sleep_prob': 0.40, 'avg_nap_duration_min': 120,'max_awake_min': 150, 'night_sleep_factor': 1.1, 'night_break_prob': 0.05}, # 6개월
            48: {'base_sleep_prob': 0.35, 'avg_nap_duration_min': 120,'max_awake_min': 180, 'night_sleep_factor': 1.05,'night_break_prob': 0.04}  # 12개월
        }
        self.env_profiles = self._initialize_environment_profiles()

    def _get_stage_params(self, week):
        stages = sorted(self.developmental_stages.keys(), reverse=True)
        for s_week_start in stages:
            if week >= s_week_start:
                return self.developmental_stages[s_week_start]
        return self.developmental_stages[0] # 기본값 (신생아)

    def _initialize_environment_profiles(self):
        profiles = {}
        for bid in self.baby_ids:
            profiles[bid] = {
                'temp': np.random.uniform(23.0, 27.0), 'humidity': np.random.uniform(50.0, 70.0),
                'brightness': np.random.uniform(70.0, 100.0), 'noise': np.random.randint(40, 70),
                'optimal_temp_day': np.random.normal(23.0, 1.0), 
                'optimal_temp_night': np.random.normal(21.0, 1.0),
                'adapt_speed': np.random.uniform(0.05, 0.2)
            }
        return profiles
    
    def _adjust_environment(self, baby_id, is_sleeping_now, current_time):
        profile = self.env_profiles[baby_id]
        hour = current_time.hour
        
        is_night = 21 <= hour or hour < 6 # 밤 시간 정의 (예: 21시 ~ 06시)

        if is_sleeping_now:
            temp_target = profile['optimal_temp_night'] if is_night else profile['optimal_temp_day']
            noise_target = np.random.randint(35, 45) # 수면 중엔 조용하게
            brightness_target = np.random.uniform(0, 20) # 수면 중엔 어둡게
        else: # 깨어있을 때
            temp_target = profile['optimal_temp_day'] + np.random.uniform(-1,1) # 약간의 변동성
            noise_target = np.random.randint(45, 60)
            brightness_target = np.random.uniform(60, 100) # 활동 시간에는 밝게

        profile['temp'] += (temp_target - profile['temp']) * profile['adapt_speed'] * np.random.uniform(0.8, 1.2)
        profile['noise'] = int(profile['noise'] + (noise_target - profile['noise']) * 0.2 * np.random.uniform(0.8, 1.2))
        profile['brightness'] += (brightness_target - profile['brightness']) * profile['adapt_speed'] * np.random.uniform(0.8,1.2)

        profile['temp'] = np.clip(profile['temp'], 18.0, 30.0)
        profile['humidity'] = np.clip(profile['humidity'] + np.random.normal(0, 0.5), 40.0, 75.0) # 습도는 천천히 변동
        profile['noise'] = np.clip(profile['noise'], 30, 80)
        profile['brightness'] = np.clip(profile['brightness'], 0, 100)

    def generate_data_for_baby(self, baby_id):
        """한 아기의 전체 기간 데이터를 생성"""
        baby_data = []
        log_id_start_value = baby_id * 10000000 # baby_id별 log_id 시작 값 다르게 (선택적)

        current_time = self.start_date
        end_simulation_time = self.start_date + timedelta(weeks=self.total_weeks)
        
        week = 0
        last_week_update_time = self.start_date
        
        # 아기 상태 변수
        current_is_sleeping = np.random.choice([True, False]) # 초기 상태 랜덤
        consecutive_sleep_logs = 0
        consecutive_awake_logs = 0
        
        # 낮잠 관련 변수
        naps_today_count = 0
        last_nap_end_time = current_time - timedelta(hours=4) # 초기값 (충분히 과거)

        # 메인 루프 (10초 간격)
        log_counter_for_baby = 0
        while current_time < end_simulation_time:
            if (current_time - last_week_update_time).days >= 7:
                week += 1
                last_week_update_time = current_time
            
            stage_params = self._get_stage_params(week)
            self._adjust_environment(baby_id, current_is_sleeping, current_time)
            profile = self.env_profiles[baby_id]
            
            current_hour = current_time.hour
            is_night_period = 21 <= current_hour or current_hour < 7 # 밤잠 시간대 (예: 21시~07시)

            # --- is_sleeping 상태 결정 로직 ---
            prob_to_sleep = stage_params['base_sleep_prob']
            prob_to_wake = 1 - prob_to_sleep

            # 1. 시간대별 조정
            if is_night_period:
                prob_to_sleep *= stage_params['night_sleep_factor']
            else: # 낮 시간
                prob_to_sleep *= 0.7 # 밤보다는 덜 잠

            # 2. 연속 각성/수면 시간 기반 조정
            if consecutive_awake_logs > stage_params['max_awake_min'] * self.logs_per_minute:
                prob_to_sleep = min(1.0, prob_to_sleep * 1.5) # 오래 깨있으면 잠들 확률 증가
            
            max_continuous_sleep_logs_day = stage_params['avg_nap_duration_min'] * 1.5 * self.logs_per_minute # 최대 낮잠 시간
            max_continuous_sleep_logs_night = 8 * 60 * self.logs_per_minute # 최대 밤잠 (예: 8시간)
            
            if current_is_sleeping:
                if is_night_period and consecutive_sleep_logs > max_continuous_sleep_logs_night:
                    prob_to_wake = min(1.0, prob_to_wake * 2.0) # 너무 오래 자면 깰 확률 증가 (밤)
                elif not is_night_period and consecutive_sleep_logs > max_continuous_sleep_logs_day:
                     prob_to_wake = min(1.0, prob_to_wake * 2.0) # 너무 오래 자면 깰 확률 증가 (낮)


            # 3. 상태 전환 결정 (매 분 또는 특정 조건마다)
            # 여기서는 더 자주 상태를 평가하도록 매 10초마다 확률 기반으로 결정
            rand_val = np.random.rand()

            if current_is_sleeping: # 현재 자고 있다면
                # 밤이고, 아주 낮은 확률로 "브레이크" 발생 (1~4분 False)
                if is_night_period and rand_val < stage_params['night_break_prob'] / (60 * self.logs_per_minute / 10) : # 10분당 1회 정도의 확률로 조정
                    break_duration_logs = np.random.randint(1 * self.logs_per_minute, 4 * self.logs_per_minute + 1)
                    for _ in range(break_duration_logs):
                        if current_time >= end_simulation_time: break
                        baby_data.append(self._create_log_entry(log_id_start_value + log_counter_for_baby, baby_id, False, current_time, profile, week))
                        log_counter_for_baby +=1
                        current_time += timedelta(seconds=self.log_interval_seconds)
                        if current_time >= end_simulation_time: break
                    # 브레이크 후에는 다시 잠든다고 가정 (또는 확률적으로 결정)
                    current_is_sleeping = True 
                    consecutive_sleep_logs = 0 # 브레이크 후 수면 시간 리셋
                    consecutive_awake_logs = 0
                    if current_time >= end_simulation_time: break
                    continue # 다음 10초 루프로

                # 일반적인 깸 확률
                if rand_val < prob_to_wake / (10 * self.logs_per_minute) : # 10분당 한번꼴 확률로 조정
                    current_is_sleeping = False
            
            else: # 현재 깨어 있다면
                if rand_val < prob_to_sleep / (10 * self.logs_per_minute) :
                    # "완전 깸" (5분 이상 False) 시나리오를 만들기 위해,
                    # 깨어있는 상태가 일정 시간 지속되도록 함.
                    # 여기서는 일단 확률로 잠들게 하지만,
                    # 실제로는 깨어난 후 바로 잠들지 않는 패턴이 더 현실적.
                    # 이 부분은 개선 여지 있음 (예: 최소 각성 시간 보장)
                    current_is_sleeping = True
            
            # 상태 지속 시간 업데이트
            if current_is_sleeping:
                consecutive_sleep_logs += 1
                consecutive_awake_logs = 0
            else:
                consecutive_awake_logs += 1
                consecutive_sleep_logs = 0

            # --- "완전 깸" (5분 이상 False) 시나리오 만들기 ---
            # 만약 깨어난 상태(current_is_sleeping=False)이고,
            # consecutive_awake_logs 가 (5분 * logs_per_minute) 보다 작다면,
            # 강제로 계속 깨어있도록 할 수도 있음. (하지만 이건 너무 인위적일 수 있음)
            # 여기서는 확률 기반으로 하되, "연속 각성 시간 기반 조정"에서 잠들 확률을 낮추는 식으로 간접 유도.

            # 로그 생성
            baby_data.append(self._create_log_entry(log_id_start_value + log_counter_for_baby, baby_id, current_is_sleeping, current_time, profile, week))
            log_counter_for_baby +=1
            current_time += timedelta(seconds=self.log_interval_seconds)

        return baby_data

    def _create_log_entry(self, log_id, baby_id, is_sleeping, timestamp, profile, week):
        return {
            "log_id": log_id, "baby_id": baby_id, "is_sleeping": is_sleeping,
            "created_at": timestamp,
            "temperature": round(profile['temp'], 1), "humidity": round(profile['humidity'], 1),
            "brightness": round(profile['brightness'], 1), "white_noise_level": profile['noise'],
            "week": week
        }

    def generate_all_data(self):
        all_data = []
        for baby_id_val in self.baby_ids:
            print(f"Simulating data for baby ID: {baby_id_val}...")
            all_data.extend(self.generate_data_for_baby(baby_id_val))
        return pd.DataFrame(all_data)

# %%
simulator = RealisticBabySimulator(baby_ids=[1, 2, 3, 4, 5], 
                                   start_date=datetime(2024, 5, 27), 
                                   total_weeks=48) # 또는 테스트를 위해 total_weeks=1 등으로 짧게
df_realistic_dummy = simulator.generate_all_data()
# Out:
# Simulating data for baby ID: 1...
# Simulating data for baby ID: 2...
# Simulating data for baby ID: 3...
# Simulating data for baby ID: 4...
# Simulating data for baby ID: 5...

# %%
df_realistic_dummy.to_csv('2nd_dummy_baby_sleep_data.csv', index=False, encoding='utf-8-sig')

# %%
print(df_realistic_dummy.head())
print(f"\nTotal logs generated: {len(df_realistic_dummy)}")
# Out:
#      log_id  baby_id  is_sleeping          created_at  temperature  humidity  \
# 0  10000000        1        False 2024-05-27 00:00:00         25.0      66.3
# 1  10000001        1        False 2024-05-27 00:00:10         24.8      66.3
# 2  10000002        1         True 2024-05-27 00:00:20         24.6      65.2
# 3  10000003        1         True 2024-05-27 00:00:30         24.0      65.4
# 4  10000004        1         True 2024-05-27 00:00:40         23.4      65.5
#
#    brightness  white_noise_level  week
# 0        78.6                 49     0
# 1        80.5                 48     0
# 2        78.1                 48     0
# 3        68.1                 45     0
# 4        60.0                 44     0
#
# Total logs generated: 14515200

# %%
# 생성된 데이터에서 is_sleeping 분포 확인
print("\nIs Sleeping Distribution:")
print(df_realistic_dummy['is_sleeping'].value_counts(normalize=True))
# Out:
# Is Sleeping Distribution:
# is_sleeping
# False    0.560444
# True     0.439556
# Name: proportion, dtype: float64

# %% [markdown]
# **주요 수정 방향:**
#
# 1.  **`is_sleeping` 상태의 동적 결정:** 이것이 가장 핵심입니다. 아기의 연령(주차), 시간대(밤/낮), 연속 수면/각성 시간 등을 고려하여 `is_sleeping` 상태가 변하도록 합니다.
# 2.  **"완전 깸" 및 "브레이크" 시나리오 명시적 생성:** 분석 함수가 감지해야 할 주요 이벤트를 더미 데이터에 포함시킵니다.
# 3.  **낮잠 로직 구체화:** `nap_count`를 활용하여 현실적인 낮잠 패턴을 시도합니다.
# 4.  **Wake Window (깨어있는 시간) 고려:** 아기가 특정 시간 이상 깨어있으면 잠들 확률을 높이는 로직을 추가합니다.
# 5.  **수면 주기(Sleep Cycle) 내의 짧은 각성(브레이크) 시뮬레이션:** 깊은 잠과 얕은 잠 사이의 전환점에서 발생할 수 있는 짧은 각성을 표현합니다.
#
# **주요 변경 및 추가 사항:**
#
# 1.  **클래스명 변경:** `RealisticBabySimulator`
# 2.  **`developmental_stages` 상세화:**
#     *   `avg_nap_duration_min` (평균 낮잠 시간)
#     *   `max_awake_min` (최대 깨어있는 시간 - Wake Window 개념)
#     *   `night_sleep_factor` (야간 수면 강화 계수)
#     *   `night_break_prob` (밤중 짧은 깸 발생 확률)
# 3.  **`generate_data_for_baby` 메서드 분리:** 각 아기별 데이터 생성을 별도 메서드로 만들어 관리 용이.
# 4.  **`is_sleeping` 상태 결정 로직:**
#     *   **상태 변수:** `current_is_sleeping`, `consecutive_sleep_logs`, `consecutive_awake_logs`를 사용하여 현재 상태와 지속 시간을 추적.
#     *   **확률 기반 전환:**
#         *   기본 수면 확률(`base_sleep_prob`)을 설정하고, 시간대(밤/낮), 연속 각성/수면 시간에 따라 이 확률을 조정.
#         *   매 10초마다 또는 특정 주기마다 랜덤 값과 조정된 확률을 비교하여 상태 전환 여부 결정. (현재는 매 10초마다 확률적으로 상태를 평가하고, 실제 전환은 더 낮은 빈도로 발생하도록 조정)
#     *   **밤중 "브레이크" 시뮬레이션:**
#         *   밤 시간 동안 `current_is_sleeping == True`일 때, `night_break_prob`에 따라 1~4분 동안 `is_sleeping = False`로 잠시 전환되는 "브레이크"를 명시적으로 생성. 브레이크 후에는 다시 잠든다고 가정 (또는 확률적으로 결정).
#     *   **"완전 깸" 유도:**
#         *   `current_is_sleeping == False`일 때, 바로 다시 잠들지 않도록 `prob_to_sleep`을 낮추거나, 최소 각성 시간을 보장하는 로직을 추가할 수 있습니다 (현재 코드는 확률 기반이며, 이 부분은 더 개선할 수 있습니다).
#         *   "너무 오래 자면 깰 확률 증가" 로직을 통해 자연스러운 깸을 유도.
# 5.  **`_create_log_entry` 메서드:** 로그 생성 부분을 함수로 분리.
# 6.  **`generate_all_data` 메서드:** 모든 아기의 데이터를 생성하고 하나의 DataFrame으로 합치는 최상위 메서드.
#
# **추가 고려 및 개선 사항:**
#
# *   **"완전 깸" (5분 이상 False) 패턴 강화:** 현재 로직은 확률 기반이라 5분 이상 연속 False가 충분히 자주 발생하지 않을 수 있습니다. 특정 조건(예: 밤잠 종료 시, 긴 낮잠 후)에서 의도적으로 5분 이상 깨어있는 기간을 만드는 것을 고려할 수 있습니다.
# *   **낮잠 스케줄링:** `nap_count`를 직접적으로 사용하여 하루에 특정 횟수의 낮잠을 자도록 유도하는 로직을 추가하면 더 현실적일 것입니다. (예: 아침에 깨어난 후 일정 시간 뒤 첫 낮잠, 그 후 Wake Window를 거쳐 다음 낮잠 등)
# *   **수면 압력(Sleep Pressure) 모델링:** 깨어있는 시간이 길어질수록 잠들 확률이 높아지고, 자는 시간이 길어질수록 깰 확률이 높아지는 것을 더 정교하게 모델링할 수 있습니다.
# *   **4개월 수면 퇴행 등 특정 이벤트:** 특정 주차에 수면 패턴이 더 불규칙해지는 현상을 시뮬레이션에 추가할 수 있습니다.
#
# 이 수정된 시뮬레이터로 생성된 데이터는 `is_sleeping` 상태가 동적으로 변하고, "브레이크"와 (이론적으로) "완전 깸" 패턴을 포함할 가능성이 훨씬 높습니다. 이 데이터를 사용하여 `analyze_sleep_cycle_details_v2` 함수를 다시 테스트해보시면 이전과는 다른, 더 의미 있는 결과를 얻으실 수 있을 것입니다.
#
# 생성된 데이터의 `is_sleeping` 분포를 확인하고, 특정 날짜의 데이터를 시각화해보는 것도 데이터가 잘 생성되었는지 판단하는 데 도움이 됩니다.

# %%
from datetime import timedelta, datetime
import logging # 로깅 라이브러리 사용

# %%
# 로거 설정 (필요한 경우에만 상세 로깅)
# logging.basicConfig(level=logging.INFO) # INFO 레벨 이상 모두 출력
# logger = logging.getLogger(__name__)

def analyze_sleep_cycle_details_v2(daily_logs_df, # 함수 이름 변경 (버전 관리)
                                   log_interval_seconds=10,
                                   min_sleep_duration_for_state_minutes=5,
                                   sleep_state_true_threshold_ratio=0.8,
                                   break_min_duration_minutes=1,
                                   awakening_min_duration_minutes=5,
                                   min_valid_chunk_duration_minutes=10,
                                   debug_date=None): # 특정 날짜 디버깅용 파라미터
    """
    하루 동안의 로그 데이터를 분석하여 주요 수면 사이클(청크)을 식별하고,
    각 청크 내의 상세 정보(실제 잠든 시간, 깬 시간, 브레이크 횟수, 수면 효율 등)를 추출합니다.
    (이전 버전에서 Warning 처리 및 디버깅 옵션 추가)
    """
    if daily_logs_df.empty:
        return []

    # 현재 날짜 (디버깅용)
    current_processing_date = None
    if not daily_logs_df.empty:
        current_processing_date = daily_logs_df['created_at'].iloc[0].date()


    if not pd.api.types.is_datetime64_any_dtype(daily_logs_df['created_at']):
        daily_logs_df['created_at'] = pd.to_datetime(daily_logs_df['created_at'])
    daily_logs_df = daily_logs_df.sort_values(by='created_at').reset_index(drop=True)
    daily_logs_df['is_sleeping_int'] = daily_logs_df['is_sleeping'].astype(int)

    logs_per_minute = 60 // log_interval_seconds
    min_logs_for_state = min_sleep_duration_for_state_minutes * logs_per_minute
    break_min_logs = break_min_duration_minutes * logs_per_minute
    awakening_min_logs = awakening_min_duration_minutes * logs_per_minute

    sleep_cycles = []
    current_log_index = 0
    num_logs = len(daily_logs_df)

    while current_log_index < num_logs:
        potential_sleep_start_index = -1
        actual_fell_asleep_time = None

        for i in range(current_log_index, num_logs - min_logs_for_state + 1):
            window = daily_logs_df.iloc[i : i + min_logs_for_state]
            if window['is_sleeping_int'].mean() >= sleep_state_true_threshold_ratio:
                potential_sleep_start_index = i
                actual_fell_asleep_time = window.iloc[0]['created_at']
                break
        
        if potential_sleep_start_index == -1:
            break

        chunk_processing_start_index = potential_sleep_start_index # '잠듦' 판단 윈도우 시작
        chunk_actual_start_time = actual_fell_asleep_time # 실제 '잠듦' 시간 (윈도우 첫 로그)

        breaks_in_chunk = 0
        is_false_streak_count = 0 # 각 청크 시작 시 리셋
        
        # `actual_fell_asleep_time` 이후부터 완전 깸 탐색 시작
        # `potential_sleep_start_index`는 윈도우의 시작이므로, 실제 탐색은 윈도우 끝 이후부터.
        # 또는, '잠듦'으로 판단된 첫 로그부터 is_sleeping 상태를 추적해도 됨.
        # 여기서는 '잠듦'으로 판단된 윈도우의 첫 로그부터 상태를 추적.
        # 즉, k는 potential_sleep_start_index 부터 시작.
        
        # 이 루프는 '잠듦'이 확인된 시점부터 데이터의 끝까지 또는 '완전 깸'이 확인될 때까지 진행
        for k in range(potential_sleep_start_index, num_logs + 1):
            # 디버깅 로그 (특정 날짜에만 출력)
            if debug_date and current_processing_date == debug_date:
                if k < num_logs:
                    print(f"DEBUG [{current_processing_date}] k={k}, is_sleeping={daily_logs_df.iloc[k]['is_sleeping']}, streak={is_false_streak_count}")
                else:
                    print(f"DEBUG [{current_processing_date}] k={k} (data end), streak={is_false_streak_count}")


            current_is_sleeping = False # k == num_logs 일 때를 대비한 기본값
            if k < num_logs: # 실제 데이터가 있는 경우
                current_is_sleeping = daily_logs_df.iloc[k]['is_sleeping']

            if current_is_sleeping:
                if is_false_streak_count >= break_min_logs and is_false_streak_count < awakening_min_logs:
                    # False 스트릭이 브레이크 조건 만족 후 True로 바뀜 -> 브레이크 카운트
                    breaks_in_chunk += 1
                is_false_streak_count = 0 # True이면 리셋
            else: # is_sleeping == False 또는 k == num_logs
                is_false_streak_count += 1
            
            # '완전 깸' 또는 '데이터 끝' 판단
            # is_false_streak_count가 awakening_min_logs에 도달했거나, k가 데이터 끝을 가리킬 때
            # (k==num_logs일때는 current_is_sleeping=False로 간주되어 is_false_streak_count가 1 증가된 상태)
            if is_false_streak_count >= awakening_min_logs or k == num_logs:
                # --- 잠 청크(수면 사이클) 종료 ---
                idx_false_started = -1
                if k == num_logs: # 데이터 끝에 도달
                    # 이 경우, is_false_streak_count는 (num_logs-1)까지의 False 연속을 반영
                    # (k==num_logs에서 is_false_streak_count가 1 더 증가했으므로 -1 해줌)
                    idx_false_started = (k - 1) - (is_false_streak_count -1) + 1 if is_false_streak_count > 0 else k
                else: # awakening_min_logs 이상 False 지속
                    idx_false_started = k - is_false_streak_count + 1
                
                actual_woke_up_time_index = max(potential_sleep_start_index, idx_false_started)
                
                if actual_woke_up_time_index >= num_logs :
                    # 이 Warning은 k=num_logs이고 streak=0 (또는 매우 작음)일 때 발생 가능
                    # 즉, 하루가 끝날 때까지 자고 있었거나, 짧게 깨고 끝난 경우.
                    # 이 경우는 정상일 수 있으므로, 로깅 레벨을 낮추거나 조건부로만 출력.
                    if debug_date and current_processing_date == debug_date:
                         print(f"INFO [{current_processing_date}]: actual_woke_up_time_index adjusted. k={k}, streak={is_false_streak_count-1 if k==num_logs else is_false_streak_count}, num_logs={num_logs}, pot_start={potential_sleep_start_index}, false_start={idx_false_started}")
                    actual_woke_up_time_index = num_logs -1 # 마지막 유효 인덱스
                    if actual_woke_up_time_index < 0 : actual_woke_up_time_index = 0 #혹시 모를 상황 대비

                actual_woke_up_time = daily_logs_df.iloc[actual_woke_up_time_index]['created_at']

                # 분석할 로그 범위: '실제 잠듦 시작 시간'부터 '실제 깬 시간' 직전까지
                start_idx_for_logs = potential_sleep_start_index # '잠듦' 판단 윈도우 시작 인덱스
                
                # actual_woke_up_time_index는 '깸'이 시작된 로그의 인덱스. 그 직전까지가 잠든 기간.
                chunk_logs_for_analysis = daily_logs_df.iloc[start_idx_for_logs : actual_woke_up_time_index]
                
                if chunk_logs_for_analysis.empty and not (start_idx_for_logs == actual_woke_up_time_index) : # 비어있지 않아야 함 (시작==끝 제외)
                     if debug_date and current_processing_date == debug_date:
                        print(f"Warning [{current_processing_date}]: chunk_logs_for_analysis is empty. start_idx={start_idx_for_logs}, woke_idx={actual_woke_up_time_index}")
                     current_log_index = k + 1 if k < num_logs else num_logs
                     break 

                total_chunk_duration_obj = actual_woke_up_time - chunk_actual_start_time
                
                if total_chunk_duration_obj < timedelta(minutes=min_valid_chunk_duration_minutes):
                    current_log_index = k + 1 if k < num_logs else num_logs
                    break 

                actual_sleep_in_chunk_count = chunk_logs_for_analysis['is_sleeping_int'].sum()
                actual_sleep_duration_obj = timedelta(seconds=int(actual_sleep_in_chunk_count * log_interval_seconds))
                
                total_duration_sec = total_chunk_duration_obj.total_seconds()
                efficiency = 0
                if total_duration_sec > 0: # 0으로 나누기 방지
                    efficiency = (actual_sleep_duration_obj.total_seconds() / total_duration_sec) * 100
                
                env_logs = chunk_logs_for_analysis
                avg_temp = env_logs['temperature'].mean()
                avg_humidity = env_logs['humidity'].mean()
                avg_brightness = env_logs['brightness'].mean()
                avg_white_noise = env_logs['white_noise_level'].mean()
                week_val = env_logs['week'].iloc[0] if not env_logs.empty else None
                
                sleep_cycles.append({
                    'cycle_start_time': chunk_actual_start_time,
                    'cycle_end_time': actual_woke_up_time,
                    'total_cycle_duration_minutes': round(max(0,total_duration_sec) / 60, 2), # 음수 방지
                    'actual_sleep_duration_minutes': round(actual_sleep_duration_obj.total_seconds() / 60, 2),
                    'sleep_efficiency_percent': round(efficiency, 2),
                    'breaks_count': breaks_in_chunk,
                    'avg_temperature': round(avg_temp, 1) if pd.notna(avg_temp) else None,
                    'avg_humidity': round(avg_humidity, 1) if pd.notna(avg_humidity) else None,
                    'avg_brightness': round(avg_brightness, 1) if pd.notna(avg_brightness) else None,
                    'avg_white_noise_level': round(avg_white_noise, 0) if pd.notna(avg_white_noise) else None,
                    'week': int(week_val) if pd.notna(week_val) else None
                })
                current_log_index = k + 1 if k < num_logs else num_logs # 다음 탐색 시작 위치 (k 다음부터)
                break # 현재 청크 처리 완료, 다음 청크 찾기 위해 외부 while 루프로

            # 브레이크 판단 로직 수정: is_sleeping == True로 돌아올 때 카운트
            # (위의 if current_is_sleeping: 블록에서 처리됨)

        if potential_sleep_start_index != -1 and not sleep_cycles : # 잠은 들었는데 사이클 못만들고 루프 끝난경우
             # 이 경우는 for k 루프가 break 없이 끝났다는 의미 (즉, 완전 깸을 못찾음)
             # 이는 while 루프의 종료 조건(current_log_index < num_logs)에 의해 처리될 것.
             # 만약 while 루프가 current_log_index 업데이트 없이 계속 돌면 무한루프 가능성 -> current_log_index 업데이트 보장 필요.
             # 위에서 current_log_index = k + 1 로 업데이트 되므로 괜찮을 것.
             pass


    return sleep_cycles

# %%
# 특정 아기, 특정 날짜의 데이터로 analyze_sleep_cycle_details_v2 테스트
# 예: baby_id=1, 첫째 날 데이터
if not df_realistic_dummy.empty:
    baby1_df = df_realistic_dummy[df_realistic_dummy['baby_id'] == 1].copy()
    if not pd.api.types.is_datetime64_any_dtype(baby1_df['created_at']):
        baby1_df.loc[:, 'created_at'] = pd.to_datetime(baby1_df['created_at'])
    
    if not baby1_df.empty:
        first_day_str = simulator.start_date.strftime('%Y-%m-%d')
        baby1_first_day_df = baby1_df[baby1_df['created_at'].dt.strftime('%Y-%m-%d') == first_day_str]

        if not baby1_first_day_df.empty:
            print(f"\nAnalyzing first day data for baby 1 ({len(baby1_first_day_df)} logs):")
            cycles = analyze_sleep_cycle_details_v2( # 이전 대화의 v2 함수 사용
                baby1_first_day_df,
                debug_date=simulator.start_date.date() # 디버깅 출력용
            )
            if cycles:
                df_cycles = pd.DataFrame(cycles)
                print(df_cycles)
            else:
                print("No sleep cycles found for the first day.")
        else:
            print("No data for the first day of baby 1.")
    else:
        print("No data for baby 1.")
# Out:
# Analyzing first day data for baby 1 (8640 logs):
# DEBUG [2024-05-27] k=0, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=1, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=2, is_sleeping=True, streak=2
# DEBUG [2024-05-27] k=3, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=4, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=5, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=6, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=7, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=9, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=10, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=11, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=12, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=13, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=14, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=15, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=16, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=17, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=18, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=19, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=20, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=21, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=22, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=23, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=24, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=25, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=26, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=27, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=28, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=29, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=30, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=31, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=32, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=33, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=34, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=35, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=36, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=37, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=38, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=39, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=40, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=41, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=42, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=43, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=44, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=45, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=46, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=47, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=48, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=49, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=50, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=51, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=52, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=53, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=54, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=55, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=56, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=57, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=58, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=59, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=60, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=61, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=62, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=63, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=64, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=65, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=66, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=67, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=68, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=69, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=70, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=71, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=72, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=73, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=74, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=75, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=76, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=77, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=78, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=79, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=80, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=81, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=82, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=83, is_sleeping=False, streak=7
# DEBUG [2024-05-27] k=84, is_sleeping=True, streak=8
# DEBUG [2024-05-27] k=85, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=86, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=87, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=88, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=89, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=90, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=91, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=92, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=93, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=94, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=95, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=96, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=97, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=98, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=99, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=100, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=101, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=102, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=103, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=104, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=105, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=106, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=107, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=108, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=109, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=110, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=111, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=112, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=113, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=114, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=115, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=116, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=117, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=118, is_sleeping=False, streak=7
# DEBUG [2024-05-27] k=119, is_sleeping=False, streak=8
# DEBUG [2024-05-27] k=120, is_sleeping=False, streak=9
# DEBUG [2024-05-27] k=121, is_sleeping=False, streak=10
# DEBUG [2024-05-27] k=122, is_sleeping=False, streak=11
# DEBUG [2024-05-27] k=123, is_sleeping=False, streak=12
# DEBUG [2024-05-27] k=124, is_sleeping=False, streak=13
# DEBUG [2024-05-27] k=125, is_sleeping=False, streak=14
# DEBUG [2024-05-27] k=126, is_sleeping=False, streak=15
# DEBUG [2024-05-27] k=127, is_sleeping=False, streak=16
# DEBUG [2024-05-27] k=128, is_sleeping=False, streak=17
# DEBUG [2024-05-27] k=129, is_sleeping=False, streak=18
# DEBUG [2024-05-27] k=130, is_sleeping=False, streak=19
# DEBUG [2024-05-27] k=131, is_sleeping=False, streak=20
# DEBUG [2024-05-27] k=132, is_sleeping=False, streak=21
# DEBUG [2024-05-27] k=133, is_sleeping=False, streak=22
# DEBUG [2024-05-27] k=134, is_sleeping=False, streak=23
# DEBUG [2024-05-27] k=135, is_sleeping=False, streak=24
# DEBUG [2024-05-27] k=136, is_sleeping=False, streak=25
# DEBUG [2024-05-27] k=137, is_sleeping=False, streak=26
# DEBUG [2024-05-27] k=138, is_sleeping=False, streak=27
# DEBUG [2024-05-27] k=139, is_sleeping=False, streak=28
# DEBUG [2024-05-27] k=140, is_sleeping=False, streak=29
# DEBUG [2024-05-27] k=215, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=216, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=217, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=218, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=219, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=220, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=221, is_sleeping=True, streak=6
# DEBUG [2024-05-27] k=222, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=223, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=224, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=225, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=226, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=227, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=228, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=229, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=230, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=231, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=232, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=233, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=234, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=235, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=236, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=237, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=238, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=239, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=240, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=241, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=242, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=243, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=244, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=245, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=246, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=247, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=248, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=249, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=250, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=251, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=252, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=253, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=254, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=255, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=256, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=257, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=258, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=259, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=260, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=261, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=262, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=263, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=264, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=265, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=266, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=267, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=268, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=269, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=270, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=271, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=272, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=273, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=274, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=275, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=276, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=277, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=278, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=279, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=280, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=281, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=282, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=283, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=284, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=285, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=286, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=287, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=288, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=289, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=290, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=291, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=292, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=293, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=294, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=295, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=296, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=297, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=298, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=299, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=300, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=301, is_sleeping=False, streak=7
# DEBUG [2024-05-27] k=302, is_sleeping=False, streak=8
# DEBUG [2024-05-27] k=303, is_sleeping=False, streak=9
# DEBUG [2024-05-27] k=304, is_sleeping=False, streak=10
# DEBUG [2024-05-27] k=305, is_sleeping=False, streak=11
# DEBUG [2024-05-27] k=306, is_sleeping=False, streak=12
# DEBUG [2024-05-27] k=307, is_sleeping=False, streak=13
# DEBUG [2024-05-27] k=308, is_sleeping=False, streak=14
# DEBUG [2024-05-27] k=309, is_sleeping=False, streak=15
# DEBUG [2024-05-27] k=310, is_sleeping=False, streak=16
# DEBUG [2024-05-27] k=311, is_sleeping=False, streak=17
# DEBUG [2024-05-27] k=312, is_sleeping=False, streak=18
# DEBUG [2024-05-27] k=313, is_sleeping=True, streak=19
# DEBUG [2024-05-27] k=314, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=315, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=316, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=317, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=318, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=319, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=320, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=321, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=322, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=323, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=324, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=325, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=326, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=327, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=328, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=329, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=330, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=331, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=332, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=333, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=334, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=335, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=336, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=337, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=338, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=339, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=340, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=341, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=342, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=343, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=344, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=345, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=346, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=347, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=348, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=349, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=350, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=351, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=352, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=353, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=354, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=355, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=356, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=357, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=358, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=359, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=360, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=361, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=362, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=363, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=364, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=365, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=366, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=367, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=368, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=369, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=370, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=371, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=372, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=373, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=374, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=375, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=376, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=377, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=378, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=379, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=380, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=381, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=382, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=383, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=384, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=385, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=386, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=387, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=388, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=389, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=390, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=391, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=392, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=393, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=394, is_sleeping=True, streak=7
# DEBUG [2024-05-27] k=395, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=396, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=397, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=398, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=399, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=400, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=401, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=402, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=403, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=404, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=405, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=406, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=407, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=408, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=409, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=410, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=411, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=412, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=413, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=414, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=415, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=416, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=417, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=418, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=419, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=420, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=421, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=422, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=423, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=424, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=425, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=426, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=427, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=428, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=429, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=430, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=431, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=432, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=433, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=434, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=435, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=436, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=437, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=438, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=439, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=440, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=441, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=442, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=443, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=444, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=445, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=446, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=447, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=448, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=449, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=450, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=451, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=452, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=453, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=454, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=455, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=456, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=457, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=458, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=459, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=460, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=461, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=462, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=463, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=464, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=465, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=466, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=467, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=468, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=469, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=470, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=471, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=472, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=473, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=474, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=475, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=476, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=477, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=478, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=479, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=480, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=481, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=482, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=483, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=484, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=485, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=486, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=487, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=488, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=489, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=490, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=491, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=492, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=493, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=494, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=495, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=496, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=497, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=498, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=499, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=500, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=501, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=502, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=503, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=504, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=505, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=506, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=507, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=508, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=509, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=510, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=511, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=512, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=513, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=514, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=515, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=516, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=517, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=518, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=519, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=520, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=521, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=522, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=523, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=524, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=525, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=526, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=527, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=528, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=529, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=530, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=531, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=532, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=533, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=534, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=535, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=536, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=537, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=538, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=539, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=540, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=541, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=542, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=543, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=544, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=545, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=546, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=547, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=548, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=549, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=550, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=551, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=552, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=553, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=554, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=555, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=556, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=557, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=558, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=559, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=560, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=561, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=562, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=563, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=564, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=565, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=566, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=567, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=568, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=569, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=570, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=571, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=572, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=573, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=574, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=575, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=576, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=577, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=578, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=579, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=580, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=581, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=582, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=583, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=584, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=585, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=586, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=587, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=588, is_sleeping=False, streak=7
# DEBUG [2024-05-27] k=589, is_sleeping=False, streak=8
# DEBUG [2024-05-27] k=590, is_sleeping=False, streak=9
# DEBUG [2024-05-27] k=591, is_sleeping=False, streak=10
# DEBUG [2024-05-27] k=592, is_sleeping=False, streak=11
# DEBUG [2024-05-27] k=593, is_sleeping=False, streak=12
# DEBUG [2024-05-27] k=594, is_sleeping=False, streak=13
# DEBUG [2024-05-27] k=595, is_sleeping=False, streak=14
# DEBUG [2024-05-27] k=596, is_sleeping=False, streak=15
# DEBUG [2024-05-27] k=597, is_sleeping=False, streak=16
# DEBUG [2024-05-27] k=598, is_sleeping=False, streak=17
# DEBUG [2024-05-27] k=599, is_sleeping=False, streak=18
# DEBUG [2024-05-27] k=600, is_sleeping=False, streak=19
# DEBUG [2024-05-27] k=601, is_sleeping=False, streak=20
# DEBUG [2024-05-27] k=602, is_sleeping=False, streak=21
# DEBUG [2024-05-27] k=603, is_sleeping=True, streak=22
# DEBUG [2024-05-27] k=604, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=605, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=606, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=607, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=608, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=609, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=610, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=611, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=612, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=613, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=614, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=615, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=616, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=617, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=618, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=619, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=620, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=621, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=622, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=623, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=624, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=625, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=626, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=627, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=628, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=629, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=630, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=631, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=632, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=633, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=634, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=635, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=636, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=637, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=638, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=639, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=640, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=641, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=642, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=643, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=644, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=645, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=646, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=647, is_sleeping=True, streak=7
# DEBUG [2024-05-27] k=648, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=649, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=650, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=651, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=652, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=653, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=654, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=655, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=656, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=657, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=658, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=659, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=660, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=661, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=662, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=663, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=664, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=665, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=666, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=667, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=668, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=669, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=670, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=671, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=672, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=673, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=674, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=675, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=676, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=677, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=678, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=679, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=680, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=681, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=682, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=683, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=684, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=685, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=686, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=687, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=688, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=689, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=690, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=691, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=692, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=693, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=694, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=695, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=696, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=697, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=698, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=699, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=700, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=701, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=702, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=703, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=704, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=705, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=706, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=707, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=708, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=709, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=710, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=711, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=712, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=713, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=714, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=715, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=716, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=717, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=718, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=719, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=720, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=721, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=722, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=723, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=724, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=725, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=726, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=727, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=728, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=729, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=730, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=731, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=732, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=733, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=734, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=735, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=736, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=737, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=738, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=739, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=740, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=741, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=742, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=743, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=744, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=745, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=746, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=747, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=748, is_sleeping=False, streak=7
# DEBUG [2024-05-27] k=749, is_sleeping=False, streak=8
# DEBUG [2024-05-27] k=750, is_sleeping=False, streak=9
# DEBUG [2024-05-27] k=751, is_sleeping=False, streak=10
# DEBUG [2024-05-27] k=752, is_sleeping=False, streak=11
# DEBUG [2024-05-27] k=753, is_sleeping=False, streak=12
# DEBUG [2024-05-27] k=754, is_sleeping=False, streak=13
# DEBUG [2024-05-27] k=755, is_sleeping=False, streak=14
# DEBUG [2024-05-27] k=756, is_sleeping=False, streak=15
# DEBUG [2024-05-27] k=757, is_sleeping=False, streak=16
# DEBUG [2024-05-27] k=758, is_sleeping=False, streak=17
# DEBUG [2024-05-27] k=759, is_sleeping=True, streak=18
# DEBUG [2024-05-27] k=760, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=761, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=762, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=763, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=764, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=765, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=766, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=767, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=768, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=769, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=770, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=771, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=772, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=773, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=774, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=775, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=776, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=777, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=778, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=779, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=780, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=781, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=782, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=783, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=784, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=785, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=786, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=787, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=788, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=789, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=790, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=791, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=792, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=793, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=794, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=795, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=796, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=797, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=798, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=799, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=800, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=801, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=802, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=803, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=804, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=805, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=806, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=807, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=808, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=809, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=810, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=811, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=812, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=813, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=814, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=815, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=816, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=817, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=818, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=819, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=820, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=821, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=822, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=823, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=824, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=825, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=826, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=827, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=828, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=829, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=830, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=831, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=832, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=833, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=834, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=835, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=836, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=837, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=838, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=839, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=840, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=841, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=842, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=843, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=844, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=845, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=846, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=847, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=848, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=849, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=850, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=851, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=852, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=853, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=854, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=855, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=856, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=857, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=858, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=859, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=860, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=861, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=862, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=863, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=864, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=865, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=866, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=867, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=868, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=869, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=870, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=871, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=872, is_sleeping=False, streak=7
# DEBUG [2024-05-27] k=873, is_sleeping=False, streak=8
# DEBUG [2024-05-27] k=874, is_sleeping=False, streak=9
# DEBUG [2024-05-27] k=875, is_sleeping=False, streak=10
# DEBUG [2024-05-27] k=876, is_sleeping=False, streak=11
# DEBUG [2024-05-27] k=877, is_sleeping=False, streak=12
# DEBUG [2024-05-27] k=878, is_sleeping=False, streak=13
# DEBUG [2024-05-27] k=879, is_sleeping=False, streak=14
# DEBUG [2024-05-27] k=880, is_sleeping=False, streak=15
# DEBUG [2024-05-27] k=881, is_sleeping=False, streak=16
# DEBUG [2024-05-27] k=882, is_sleeping=False, streak=17
# DEBUG [2024-05-27] k=883, is_sleeping=False, streak=18
# DEBUG [2024-05-27] k=884, is_sleeping=False, streak=19
# DEBUG [2024-05-27] k=885, is_sleeping=False, streak=20
# DEBUG [2024-05-27] k=886, is_sleeping=False, streak=21
# DEBUG [2024-05-27] k=887, is_sleeping=False, streak=22
# DEBUG [2024-05-27] k=888, is_sleeping=False, streak=23
# DEBUG [2024-05-27] k=889, is_sleeping=False, streak=24
# DEBUG [2024-05-27] k=890, is_sleeping=False, streak=25
# DEBUG [2024-05-27] k=891, is_sleeping=False, streak=26
# DEBUG [2024-05-27] k=892, is_sleeping=False, streak=27
# DEBUG [2024-05-27] k=893, is_sleeping=False, streak=28
# DEBUG [2024-05-27] k=894, is_sleeping=False, streak=29
# DEBUG [2024-05-27] k=1008, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=1009, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=1010, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=1011, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=1012, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=1013, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=1014, is_sleeping=True, streak=6
# DEBUG [2024-05-27] k=1015, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1016, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1017, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1018, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1019, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1020, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1021, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1022, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1023, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1024, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1025, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1026, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1027, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1028, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1029, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1030, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1031, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1032, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1033, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1034, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1035, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1036, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1037, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1038, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1039, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1040, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1041, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1042, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1043, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1044, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1045, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1046, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1047, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1048, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1049, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1050, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1051, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1052, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1053, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1054, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1055, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1056, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1057, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1058, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1059, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1060, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1061, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1062, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1063, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1064, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1065, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1066, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1067, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1068, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1069, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1070, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1071, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1072, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1073, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1074, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1075, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1076, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1077, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1078, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1079, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1080, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1081, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1082, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1083, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1084, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1085, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1086, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=1087, is_sleeping=True, streak=0
# ...
# DEBUG [2024-05-27] k=8426, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8427, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8428, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8429, is_sleeping=False, streak=0
# DEBUG [2024-05-27] k=8430, is_sleeping=False, streak=1
# DEBUG [2024-05-27] k=8431, is_sleeping=False, streak=2
# DEBUG [2024-05-27] k=8432, is_sleeping=False, streak=3
# DEBUG [2024-05-27] k=8433, is_sleeping=False, streak=4
# DEBUG [2024-05-27] k=8434, is_sleeping=False, streak=5
# DEBUG [2024-05-27] k=8435, is_sleeping=False, streak=6
# DEBUG [2024-05-27] k=8436, is_sleeping=False, streak=7
# DEBUG [2024-05-27] k=8437, is_sleeping=False, streak=8
# DEBUG [2024-05-27] k=8438, is_sleeping=False, streak=9
# DEBUG [2024-05-27] k=8439, is_sleeping=False, streak=10
# DEBUG [2024-05-27] k=8440, is_sleeping=False, streak=11
# DEBUG [2024-05-27] k=8441, is_sleeping=False, streak=12
# DEBUG [2024-05-27] k=8442, is_sleeping=False, streak=13
# DEBUG [2024-05-27] k=8443, is_sleeping=False, streak=14
# DEBUG [2024-05-27] k=8444, is_sleeping=False, streak=15
# DEBUG [2024-05-27] k=8445, is_sleeping=False, streak=16
# DEBUG [2024-05-27] k=8446, is_sleeping=False, streak=17
# DEBUG [2024-05-27] k=8447, is_sleeping=False, streak=18
# DEBUG [2024-05-27] k=8448, is_sleeping=False, streak=19
# DEBUG [2024-05-27] k=8449, is_sleeping=True, streak=20
# DEBUG [2024-05-27] k=8450, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8451, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8452, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8453, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8454, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8455, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8456, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8457, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8458, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8459, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8460, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8461, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8462, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8463, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8464, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8465, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8466, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8467, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8468, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8469, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8470, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8471, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8472, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8473, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8474, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8475, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8476, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8477, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8478, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8479, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8480, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8481, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8482, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8483, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8484, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8485, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8486, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8487, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8488, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8489, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8490, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8491, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8492, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8493, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8494, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8495, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8496, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8497, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8498, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8499, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8500, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8501, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8502, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8503, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8504, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8505, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8506, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8507, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8508, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8509, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8510, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8511, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8512, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8513, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8514, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8515, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8516, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8517, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8518, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8519, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8520, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8521, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8522, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8523, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8524, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8525, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8526, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8527, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8528, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8529, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8530, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8531, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8532, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8533, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8534, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8535, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8536, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8537, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8538, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8539, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8540, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8541, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8542, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8543, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8544, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8545, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8546, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8547, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8548, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8549, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8550, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8551, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8552, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8553, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8554, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8555, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8556, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8557, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8558, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8559, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8560, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8561, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8562, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8563, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8564, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8565, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8566, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8567, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8568, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8569, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8570, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8571, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8572, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8573, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8574, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8575, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8576, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8577, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8578, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8579, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8580, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8581, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8582, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8583, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8584, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8585, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8586, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8587, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8588, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8589, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8590, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8591, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8592, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8593, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8594, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8595, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8596, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8597, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8598, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8599, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8600, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8601, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8602, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8603, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8604, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8605, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8606, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8607, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8608, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8609, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8610, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8611, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8612, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8613, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8614, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8615, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8616, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8617, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8618, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8619, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8620, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8621, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8622, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8623, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8624, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8625, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8626, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8627, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8628, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8629, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8630, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8631, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8632, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8633, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8634, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8635, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8636, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8637, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8638, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8639, is_sleeping=True, streak=0
# DEBUG [2024-05-27] k=8640 (data end), streak=0
# INFO [2024-05-27]: actual_woke_up_time_index adjusted. k=8640, streak=0, num_logs=8640, pot_start=7613, false_start=8640
#       cycle_start_time      cycle_end_time  total_cycle_duration_minutes  \
# 0  2024-05-27 00:00:00 2024-05-27 00:18:30                         18.50
# 1  2024-05-27 00:35:50 2024-05-27 02:24:10                        108.33
# 2  2024-05-27 02:48:00 2024-05-27 04:29:50                        101.83
# 3  2024-05-27 04:35:40 2024-05-27 06:15:10                         99.50
# 4  2024-05-27 06:46:40 2024-05-27 07:03:20                         16.67
# 5  2024-05-27 07:17:30 2024-05-27 07:46:00                         28.50
# 6  2024-05-27 08:03:40 2024-05-27 08:21:00                         17.33
# 7  2024-05-27 08:44:10 2024-05-27 09:39:20                         55.17
# 8  2024-05-27 10:00:40 2024-05-27 10:39:30                         38.83
# 9  2024-05-27 11:11:50 2024-05-27 11:49:10                         37.33
# 10 2024-05-27 11:54:10 2024-05-27 12:12:10                         18.00
# 11 2024-05-27 13:29:00 2024-05-27 14:20:20                         51.33
# 12 2024-05-27 14:54:00 2024-05-27 15:45:20                         51.33
# 13 2024-05-27 16:52:50 2024-05-27 18:32:20                         99.50
# 14 2024-05-27 18:43:50 2024-05-27 19:11:20                         27.50
# 15 2024-05-27 19:49:10 2024-05-27 20:29:50                         40.67
# 16 2024-05-27 21:08:50 2024-05-27 23:59:50                        171.00
#
#     actual_sleep_duration_minutes  sleep_efficiency_percent  breaks_count  \
# 0                           16.83                     90.99             1
# 1                           95.17                     87.85             6
# 2                           95.67                     93.94             3
# 3                           92.17                     92.63             4
# 4                           13.00                     78.00             2
# 5                           27.50                     96.49             1
# 6                           16.33                     94.23             1
# 7                           54.17                     98.19             1
# 8                           37.83                     97.42             1
# 9                           36.33                     97.32             1
# 10                          17.33                     96.30             0
# 11                          50.33                     98.05             1
# 12                          50.33                     98.05             1
# 13                          98.50                     98.99             1
# 14                          26.50                     96.36             1
# 15                          39.67                     97.54             1
# 16                         159.50                     93.27             5
#
#     avg_temperature  avg_humidity  avg_brightness  avg_white_noise_level  week
# 0              21.2          62.2            15.6                   38.0     0
# 1              21.0          49.8            11.4                   38.0     0
# 2              21.0          48.0            11.9                   38.0     0
# 3              21.5          54.9            12.9                   37.0     0
# 4              24.1          66.0            18.6                   39.0     0
# 5              24.1          67.5            14.6                   38.0     0
# 6              24.1          71.9            18.2                   38.0     0
# 7              24.1          61.5            12.8                   38.0     0
# 8              24.1          65.8            14.0                   37.0     0
# 9              24.1          64.2            13.7                   38.0     0
# 10             24.1          60.8            15.1                   38.0     0
# 11             24.1          61.1            12.1                   38.0     0
# 12             24.1          62.5            12.5                   38.0     0
# 13             24.1          71.2            11.5                   38.0     0
# 14             24.1          67.5            14.8                   38.0     0
# 15             24.1          72.3            13.9                   37.0     0
# 16             20.9          64.5            11.1                   37.0     0
